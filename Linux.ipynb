# %%
# %%writefile processCreation.sh
# #!/bin/bash
#
# echo "Parent Process ID: $$"
#
# (
# echo "Child 1 Process ID: $$, Parent Process ID: $PPID"
# sleep 5
# )&
#
# (
# echo "Child 2 Process ID: $$, Parent Process ID: $PPID"
# sleep 5
# )&
#
# sleep 1
# echo -e "\nProcess Tree:"
# ps -o pid,ppid,cmd --forest | grep -E "bash|sleep" | grep -v "grep"
# Out:
# Writing processCreation.sh

# %%
# !chmod +x processCreation.sh

# %%
# !bash processCreation.sh
# Out:
# Parent Process ID: 1571
# Child 1 Process ID: 1571, Parent Process ID: 216
# Child 2 Process ID: 1571, Parent Process ID: 216
#
# Process Tree:
#      21       7  \_ /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
#    1580      21  |   \_ sleep 1
#    1571     216  |       \_ bash processCreation.sh
#    1572    1571  |           \_ bash processCreation.sh
#    1573    1572  |           |   \_ sleep 5
#    1574    1571  |           \_ bash processCreation.sh
#    1576    1574  |           |   \_ sleep 5
#      23       1 /bin/bash -e /datalab/run.sh
